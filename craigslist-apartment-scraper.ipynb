# %%
import requests
import bs4
import json
from time import sleep
from random import randint
import csv

def parse_main_page(location='washingtondc', pages=1):

    base_url = '.craigslist.org/search/apa'
    page_url = '?s='
    headers = {'User-agent':'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.0.1) Gecko/2008071615 Fedora/3.0.1-1.fc9 Firefox/3.0.1'}
    
    main_results = []

    try:
        for n in range(1, pages+1):

            #random time delay for scraping
            sleep(randint(0,2))

            url = ''.join(['http://', location, base_url, page_url, str(n)])

            print('Processing main page %s of %s %s' % (str(n), str(pages), url))
                        
            r = requests.get(url, headers=headers)
            #print(r.status_code)
            
            # get listing information from div
            soup = bs4.BeautifulSoup(r.text, "lxml")
            listings = soup.find("div", {"class" : "content"}).find_all( "p", {"class" : "row"})
            
            #    <p class="row"
            #        data-pid="5551948979">
            #       <a href="/doc/apa/5551948979.html"
            #          class="i"
            #          data-ids=
            #          "1:00p0p_HivHZ10KR8,1:00K0K_h7JVwyiRbKO,1:00h0h_aKUUkULg1Vj,1:00C0C_kuO08O1oF9J,1:00f0f_gstUq0cYY7K,1:00W0W_aKv6LZZcsns,1:00o0o_elJBTqG91kZ,1:00808_kRXn5TIdQXh,1:00606_97sSZO7EEMt,1:00x0x_42y2gBYTv5f,1:00h0h_izI9CW1W6r6,1:00O0O_cz9jTJHKe6P,1:01414_8iGEqIx4PNM,1:00j0j_39oRWXiCYLe,1:00Q0Q_lBvfBEkanpI,1:01616_b5jurKtL2BR,1:00R0R_6vbzZDXvoH5,1:00J0J_gMveNsnijJI">
            #       </a> <span class="txt"> <span class="pl">Apr 22 <a href="/doc/apa/5551948979.html"
            #          data-id="5551948979"
            #          class="hdrlnk"><span id="titletextonly">Second Floor 1BR in
            #          Clarendon</span></a></span> <span class="l2"><span class="price">$2335</span>
            #          <span class="housing">/ 685ft<sup>2</sup> -</span> <span class=
            #          "pnr"><small>(3000 N. Washington Blvd.)</small> <span class="px"><span class=
            #          "p">pic <span class="maptag"
            #             data-pid="5551948979">map</span></span></span></span></span> <span class=
            #             "js-only banish-unbanish"> </span></span>
            #     </p>

            
            # iterate through listing data on main page
            for listing in listings:
                
                #print(listing.prettify())
                      
                _dat = {}
                _dat['index_url'] = url
                _dat['location'] = location
                _dat['page'] = n
                _dat['item_id'] = listing['data-pid']
                _dat['listing_url'] = listing.find("a")['href']
                _dat['listing_date'] = listing.find("time")['datetime']
                _dat['title'] = listing.find("span", {"id" : "titletextonly"}).text

                # some listings don't have a price
                if listing.find("span", {"class" : "price"}):
                    _dat['price'] = listing.find("span", {"class" : "price"}).text.replace('$', '').replace(',', '')
                
                
                #print(_dat['listing_url'])
                                
                # get additional information from listing page
                _dat = parse_listing_page(_dat)
                
                #print(_dat)

                main_results.append(_dat)
            
    except:
        print('This page did not return results: %s ' % url)

    print('Done processing main page')
    return main_results

def parse_listing_page(_dat):
    
    listing_base_url = '.craigslist.org'
    headers = {'User-agent':'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.0.1) Gecko/2008071615 Fedora/3.0.1-1.fc9 Firefox/3.0.1'}

    try:
        
        #random time delay for scraping
        sleep(randint(0,2))

        url = ''.join(['http://',  _dat['location'], listing_base_url, _dat['listing_url']])

        print('Processing listing page %s' % url)

        r = requests.get(url, headers=headers)
        #print(r.status_code)

        soup = bs4.BeautifulSoup(r.text, "lxml")
                
        #listing time
        try:
            
            _dat['posted_on'] = soup.find("time", {"class" : "timeago"}).text
            
        except:
            print('  Failed getting listing time: %s' % url)

        #lat/lon
        try:
            
            _dat['lat'] = soup.find("div", {"id" : "map"})['data-latitude']
            _dat['lon'] = soup.find("div", {"id" : "map"})['data-longitude']
            
        except:
            print('  Failed getting lat/long: %s' % url)

        #neighborhood
        try:
            
            _dat['neighborhood'] = soup.find("div", {"class" : "mapaddress"}).text
            
        except:
            print('  Failed getting neighborhood: %s' % url)

        #post body
        try:
            
            _dat['post_body'] = soup.find("section", {"id" : "postingbody"}).text
            
        except:
            print('  Failed getting post body: %s' % url)

        
                

    except:
        print('Error getting listing details for: %s' % url)
    
    return _dat


if __name__ == '__main__':

    location = 'washingtondc'
    
    #get results
    listings = parse_main_page(location=location, pages=1)
    
    df = pd.DataFrame.from_dict(listings, dtype=None)
    
    print(df.head())

    #create filename
    filename = location.replace('--', '_').replace('-', '_').lower() + '.csv'
    
    #get all keys
    headings = sorted(list(set().union(*(d.keys() for d in listings))))
    
    #write to csv file
    with open(filename, 'w') as output_file:
        dict_writer = csv.DictWriter(output_file, headings)
        dict_writer.writeheader()
        dict_writer.writerows(listings)
# Out:
# Processing main page 1 of 1 http://washingtondc.craigslist.org/search/apa?s=1
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5540494476.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5546173750.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5535079834.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5526026336.html
#   Failed getting lat/long: http://washingtondc.craigslist.org/nva/apa/5526026336.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5526026336.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5552180360.html
#   Failed getting lat/long: http://washingtondc.craigslist.org/mld/apa/5552180360.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/mld/apa/5552180360.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552187871.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5552187871.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552187357.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5552187357.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552186727.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5552186727.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552186058.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5552186058.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5513715497.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552185526.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5552185526.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5544665554.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/doc/apa/5544665554.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5540481900.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5552159999.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5552182610.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552082981.html
#   Failed getting lat/long: http://washingtondc.craigslist.org/nva/apa/5552082981.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5552082981.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5545472587.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5536251910.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552166662.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5538124181.html
#   Failed getting lat/long: http://washingtondc.craigslist.org/nva/apa/5538124181.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5538124181.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552163830.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5541297285.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5548079193.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5548079193.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5525990783.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/mld/apa/5525990783.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552155104.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5529811250.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5552169399.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5541561904.html
#   Failed getting lat/long: http://washingtondc.craigslist.org/nva/apa/5541561904.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5541561904.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5541858198.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5548158875.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/doc/apa/5548158875.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5541558311.html
#   Failed getting lat/long: http://washingtondc.craigslist.org/nva/apa/5541558311.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5541558311.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5505816801.html
#   Failed getting lat/long: http://washingtondc.craigslist.org/doc/apa/5505816801.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/doc/apa/5505816801.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5552163705.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5542517829.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5552160248.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552160062.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5511579555.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5552108350.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/doc/apa/5552108350.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5552157753.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5544592908.html
#   Failed getting lat/long: http://washingtondc.craigslist.org/doc/apa/5544592908.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/doc/apa/5544592908.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552155115.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5552155115.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5545691807.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552130942.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5528052065.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5548389746.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5548389746.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5552140014.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5541193028.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/doc/apa/5541193028.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5548459858.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5547347381.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5540771380.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5552028428.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5548812146.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5527650155.html
#   Failed getting lat/long: http://washingtondc.craigslist.org/mld/apa/5527650155.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/mld/apa/5527650155.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5539190256.html
#   Failed getting lat/long: http://washingtondc.craigslist.org/nva/apa/5539190256.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5539190256.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5526539467.html
#   Failed getting lat/long: http://washingtondc.craigslist.org/doc/apa/5526539467.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/doc/apa/5526539467.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5539127377.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5545501608.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5529141240.html
#   Failed getting lat/long: http://washingtondc.craigslist.org/nva/apa/5529141240.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5529141240.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5520479819.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/doc/apa/5520479819.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5552143226.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/mld/apa/5552143226.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5535502531.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/doc/apa/5535502531.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5552124860.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5552142187.html
#   Failed getting lat/long: http://washingtondc.craigslist.org/doc/apa/5552142187.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/doc/apa/5552142187.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5548400617.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5548415852.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5548405487.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5548422829.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5508417817.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5508417817.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5548410366.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5548419434.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5548425905.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5548455968.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5543756739.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/doc/apa/5543756739.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5552137355.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5542197108.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5552134319.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5530778705.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5535009821.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552131996.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5552131996.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5548779737.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5531123775.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5552128846.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/doc/apa/5552128846.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552128714.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5533217879.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552127130.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552111173.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/nva/apa/5552111173.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5543128226.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/doc/apa/5543128226.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5544109311.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552122516.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5552122372.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5544116694.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5552107356.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/doc/apa/5552107356.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5517474706.html
# Processing listing page http://washingtondc.craigslist.org/doc/apa/5552030067.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5513264762.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5552120232.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5552119769.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/mld/apa/5552119769.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5513442603.html
# Processing listing page http://washingtondc.craigslist.org/mld/apa/5537046818.html
#   Failed getting neighborhood: http://washingtondc.craigslist.org/mld/apa/5537046818.html
# Processing listing page http://washingtondc.craigslist.org/nva/apa/5513456956.html
# Done processing main page
#                                            index_url     item_id        lat  \
# 0  http://washingtondc.craigslist.org/search/apa?s=1  5540494476  38.873362
# 1  http://washingtondc.craigslist.org/search/apa?s=1  5546173750  38.901337
# 2  http://washingtondc.craigslist.org/search/apa?s=1  5535079834  38.989978
# 3  http://washingtondc.craigslist.org/search/apa?s=1  5526026336        NaN
# 4  http://washingtondc.craigslist.org/search/apa?s=1  5552180360        NaN
#
#        listing_date               listing_url      location         lon  \
# 0  2016-04-22 20:04  /nva/apa/5540494476.html  washingtondc  -77.149789
# 1  2016-04-22 20:03  /doc/apa/5546173750.html  washingtondc  -77.051711
# 2  2016-04-22 20:00  /mld/apa/5535079834.html  washingtondc  -76.973788
# 3  2016-04-22 19:59  /nva/apa/5526026336.html  washingtondc         NaN
# 4  2016-04-22 19:58  /mld/apa/5552180360.html  washingtondc         NaN
#
#                                 neighborhood  page  \
# 0                      6200 Wilson Boulevard     1
# 1                   922 24th St. NW at K St.     1
# 2  Old Columbia Pike at Carriage House Drive     1
# 3                                        NaN     1
# 4                                        NaN     1
#
#                                                                                              post_body  \
# 0  \n        I have  Two Bedroom Apt. for rent for the next 6 months (  May thr. Oct. ).  This is l...
# 1  \n        922 24th St. NW Washington, DC 20037\n                                                ...
# 2  \n        *Montgomery County sports editor seeks quiet, clean professional for completely-furnis...
# 3  \n        Available June 18th, 2016!!!  Great 1BR/1BA apartment on cul-de-sac in coveted Fairlin...
# 4  \n 1 Bed 1 Bath -- 1bed / 1 bath / 770 sq ft / $1,350* Maplewood Villas 24 Crestwood Dr. #A Gait...
#
#             posted_on price  \
# 0  2016-04-15 12:51pm  1600
# 1  2016-04-19  8:22am  1595
# 2  2016-04-12 12:16am  1150
# 3  2016-04-06 10:36am  1750
# 4  2016-04-22  7:51pm  1350
#
#                                                                 title
# 0                                             I Rent Two Bedroom Apt.
# 1                               GWU/Foggy Bottom Metro/Kennedy Center
# 2  A Little Taste of Williamsburg: Fully-Furnished Basement Apartment
# 3                                        Fairlington Village, 1BR/1BA
# 4                                Gourmet Kitchens at Maplewood Villas
